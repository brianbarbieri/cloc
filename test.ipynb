# %%
from cloc import main, show_empty_lines

# %%
directory = "C:/Users/brian/Documents/Python/Protura"
git_ignore_path = "C:/Users/brian/Documents/Python/Protura/.ignorecount"

# %%
# Example usage
main(directory, git_ignore_path)
# Out:
# -------------------------------------------------------------------------------
# Extension            # of files           # of lines           # of empty lines
# -------------------------------------------------------------------------------
# .html                130                  16383                2464
# .py                  62                   5579                 1662
# .css                 40                   4390                 1056
# .js                  41                   3534                 936
# .csv                 2                    1145                 0
# .json                1                    197                  0
# .md                  1                    38                   16
# .txt                 3                    30                   0
# no_ext               1                    1                    0
# -------------------------------------------------------------------------------
# ...

# %%
show_empty_lines(directory, git_ignore_path)
# Out:
# File: C:/Users/brian/Documents/Python/Protura\README.md
# On lines: [3, 21, 23, 28, 33, 35, 36, 41]
# File: C:/Users/brian/Documents/Python/Protura\run.py
# On lines: [1]
# File: C:/Users/brian/Documents/Python/Protura\upload_data.py
# On lines: [5, 8, 12, 22, 28]
# File: C:/Users/brian/Documents/Python/Protura\wsgi.py
# On lines: [1]
# File: C:/Users/brian/Documents/Python/Protura\protura\commands.py
# On lines: [2, 6, 11, 16, 23, 46, 51, 52, 65, 70, 71]
# File: C:/Users/brian/Documents/Python/Protura\protura\config.py
# On lines: [1, 11, 14, 21]
# File: C:/Users/brian/Documents/Python/Protura\protura\encoder.py
# On lines: [1, 4]
# File: C:/Users/brian/Documents/Python/Protura\protura\enums.py
# On lines: [1, 4]
# File: C:/Users/brian/Documents/Python/Protura\protura\models.py
# ...
